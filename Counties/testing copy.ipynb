# %%
import pandas as pd

# Creating the DataFrame
data = {
    "Unnamed: 0": [
        "Diseases of heart", "Malignant neoplasms", "Cerebrovascular diseases (stroke)",
        "Chronic lower respiratory diseases", "Accidents", "Alzheimer's disease",
        "Nephritis, nephrotic syndrome and nephrosis", "Diabetes mellitus", "Influenza and pneumonia",
        "Septicemia", "Intentional self-harm (suicide)", "Chronic liver disease and cirrhosis", "All other causes"
    ],
    "2009": [24891, 24159, 5298, 5243, 3958, 2896, 2740, 2688, 2412, 1993, 1166, 1111, 21341],
    "2010": [24868, 24016, 5333, 5219, 3961, 2915, 2607, 2499, 2205, 1858, 1169, 1119, 21855],
    "2011": [24607, 23852, 5324, 5369, 3510, 2896, 2361, 2658, 2394, 1828, 1041, 1121, 24330]
}

df = pd.DataFrame(data)

# Displaying the DataFrame
df
# Out:
#                                      Unnamed: 0   2009   2010   2011
# 0                             Diseases of heart  24891  24868  24607
# 1                           Malignant neoplasms  24159  24016  23852
# 2             Cerebrovascular diseases (stroke)   5298   5333   5324
# 3            Chronic lower respiratory diseases   5243   5219   5369
# 4                                     Accidents   3958   3961   3510
# 5                           Alzheimer's disease   2896   2915   2896
# 6   Nephritis, nephrotic syndrome and nephrosis   2740   2607   2361
# 7                             Diabetes mellitus   2688   2499   2658
# 8                       Influenza and pneumonia   2412   2205   2394
# 9                                    Septicemia   1993   1858   1828
# 10              Intentional self-harm (suicide)   1166   1169   1041
# 11          Chronic liver disease and cirrhosis   1111   1119   1121
# 12                             All other causes  21341  21855  24330

# %%
df["sum"] = df["2009"] + df["2010"] + df["2011"]
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot.bar(x='Unnamed: 0', y='sum', legend=False, title='Sum of Deaths by Cause')
# Out:
# <Axes: title={'center': 'Sum of Deaths by Cause'}, xlabel='Unnamed: 0'>
